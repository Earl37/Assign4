# %%
import pandas as pd


df = pd.read_csv(r'C:\Users\arubombora\PycharmProjects\Assignment 4\Netflix_shows_movies.csv')

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
# Drop rows with missing values
df_cleaned = df.dropna()

# %%
# Drop columns with missing values
df_cleaned = df.dropna(axis=1)

# %%
# View the first few rows
print(df.head())

# Get basic information about the DataFrame
print(df.info())  # Column types, non-null counts, memory usage

# Check for any missing values
print(df.isnull().sum())

# View summary statistics for numerical columns
print(df.describe())
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# ...

# %%
# Summary for categorical columns
print(df['show_id'].value_counts())

# Proportions for categorical columns
print(df['show_id'].value_counts(normalize=True))
# Out:
# show_id
# 81145628    1
# 81019391    1
# 81135440    1
# 81188871    1
# 80004478    1
#            ..
# 80082242    1
# 80126485    1
# 80162210    1
# 80206758    1
# 70153404    1
# Name: count, Length: 6234, dtype: int64
# show_id
# 81145628    0.00016
# 81019391    0.00016
# 81135440    0.00016
# 81188871    0.00016
# 80004478    0.00016
#              ...
# 80082242    0.00016
# 80126485    0.00016
# 80162210    0.00016
# 80206758    0.00016
# 70153404    0.00016
# Name: proportion, Length: 6234, dtype: float64

# %%
import matplotlib.pyplot as plt

df['show_id'].hist(bins=80)  
plt.show()

# %%
import matplotlib.pyplot as plt

df['type'].hist(bins=5)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

df['release_year'].hist(bins=80)
# Out:
# <Axes: >

# %%
# Summary for categorical columns
print(df['listed_in'].value_counts())

# Proportions for categorical columns
print(df['listed_in'].value_counts(normalize=True))
# Out:
# listed_in
# Documentaries                                       299
# Stand-Up Comedy                                     273
# Dramas, International Movies                        248
# Dramas, Independent Movies, International Movies    186
# Comedies, Dramas, International Movies              174
#                                                    ...
# TV Comedies, TV Dramas, TV Mysteries                  1
# Classic Movies, Dramas, LGBTQ Movies                  1
# Crime TV Shows, TV Dramas, TV Sci-Fi & Fantasy        1
# Docuseries, Reality TV, Teen TV Shows                 1
# Reality TV, Spanish-Language TV Shows                 1
# Name: count, Length: 461, dtype: int64
# listed_in
# Documentaries                                       0.047963
# Stand-Up Comedy                                     0.043792
# Dramas, International Movies                        0.039782
# Dramas, Independent Movies, International Movies    0.029836
# ...

# %%
# Summary for categorical columns
print(df['rating'].value_counts())

# Proportions for categorical columns
print(df['rating'].value_counts(normalize=True))
# Out:
# rating
# TV-MA       2027
# TV-14       1698
# TV-PG        701
# R            508
# PG-13        286
# NR           218
# PG           184
# TV-Y7        169
# TV-G         149
# TV-Y         143
# TV-Y7-FV      95
# G             37
# UR             7
# NC-17          2
# Name: count, dtype: int64
# rating
# TV-MA       0.325675
# TV-14       0.272815
# TV-PG       0.112629
# R           0.081620
# PG-13       0.045951
# NR          0.035026
# PG          0.029563
# TV-Y7       0.027153
# TV-G        0.023940
# TV-Y        0.022976
# TV-Y7-FV    0.015263
# G           0.005945
# UR          0.001125
# NC-17       0.000321
# Name: proportion, dtype: float64

# %%
# Check the first few rows of the 'listed_in' column to understand its structure
print(df['listed_in'].head())
# Out:
# 0    Children & Family Movies, Comedies
# 1                       Stand-Up Comedy
# 2                              Kids' TV
# 3                              Kids' TV
# 4                              Comedies
# Name: listed_in, dtype: object

# %%
# Split the genres and explode the lists into separate rows
genres = df['listed_in'].str.split(',').explode().str.strip()

# View the first few entries
print(genres.head())
# Out:
# 0    Children & Family Movies
# 0                    Comedies
# 1             Stand-Up Comedy
# 2                    Kids' TV
# 3                    Kids' TV
# Name: listed_in, dtype: object

# %%
genre_counts = genres.value_counts()

# Display the top genres
print(genre_counts.head())
# Out:
# listed_in
# International Movies      1927
# Dramas                    1623
# Comedies                  1113
# International TV Shows    1001
# Documentaries              668
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="darkgrid")

# Plot the top 10 most common genres
plt.figure(figsize=(10, 6))
genre_counts.head(10).plot(kind='bar', color='skyblue')

plt.title('Most Watched Genres', fontsize=18)
plt.xlabel('Genre', fontsize=12)
plt.ylabel('Number of Movies', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
import pandas as pd

# Load the dataset (adjust the file path as necessary)
df = pd.read_csv(r'C:\Users\arubombora\PycharmProjects\Assignment 4\Netflix_shows_movies.csv')

# %%
print(df['rating'].head())  # Check the first few entries of the rating column
# Out:
# 0       TV-PG
# 1       TV-MA
# 2    TV-Y7-FV
# 3       TV-Y7
# 4       TV-14
# Name: rating, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plot
sns.set(style="ticks")

# Plot the histogram for the 'rating' column
plt.figure(figsize=(12, 8))
sns.histplot(df['rating'], kde=True, color='skyblue', bins=25)

# Title and labels
plt.title('Ratings Distribution', fontsize=18)
plt.xlabel('Rating', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.show()
